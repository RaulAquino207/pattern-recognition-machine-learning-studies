# %% [markdown]
# ## Questão 1

# %%
#imports.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import StratifiedShuffleSplit, RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
df_ex5 = pd.read_csv('./dados-ex5.txt', names=['x1','x2','y'])
df_ex5
# Out:
#            x1        x2    y
# 0    0.771744 -0.548086  1.0
# 1    0.189416 -0.261982  1.0
# 2    0.918359  0.443277  0.0
# 3    1.021213 -0.488523  1.0
# 4    1.178442 -0.369193  1.0
# ..        ...       ...  ...
# 895  1.531981 -0.218318  1.0
# 896  0.038770 -0.219614  1.0
# 897 -0.641807  0.325579  0.0
# 898  0.628552  1.141872  0.0
# 899  0.102993  0.200450  1.0
#
# [900 rows x 3 columns]

# %%
X = np.array(df_ex5.iloc[:,0:2])
y = np.array(df_ex5.iloc[:, -1])

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.20)

for train_index, test_index in sss.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
plt.show()

# %%
# Model pre-loadings:
mlp_clf = MLPClassifier(solver='adam', learning_rate='adaptive',max_iter=1300,
                        learning_rate_init=5e-04, tol=1e-4)

classifier = {'MLP': mlp_clf}
param_dist_dict = {'MLP': {"hidden_layer_sizes": list(np.arange(2,500))}}

random_search = dict((k,[]) for k in classifier.keys())

for clf in param_dist_dict.keys():
    print('--------------------------', clf, '--------------------------')
    random_search[clf] = RandomizedSearchCV(classifier[clf], param_dist_dict[clf], cv=3, n_iter=5, 
                                            verbose=5, scoring='accuracy')
    random_search[clf].fit(X_train, y_train)
# Out:
# -------------------------- MLP --------------------------
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] hidden_layer_sizes=19 ...........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /home/raul/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV] ............... hidden_layer_sizes=19, score=0.967, total=   1.5s
# [CV] hidden_layer_sizes=19 ...........................................
# [CV] ............... hidden_layer_sizes=19, score=0.879, total=   0.5s
# [CV] hidden_layer_sizes=19 ...........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# /home/raul/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.0s remaining:    0.0s
# [CV] ............... hidden_layer_sizes=19, score=0.929, total=   1.9s
# [CV] hidden_layer_sizes=301 ..........................................
# [CV] .............. hidden_layer_sizes=301, score=0.988, total=   2.6s
# [CV] hidden_layer_sizes=301 ..........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.6s remaining:    0.0s
# [CV] .............. hidden_layer_sizes=301, score=0.996, total=   2.7s
# [CV] hidden_layer_sizes=301 ..........................................
# [CV] .............. hidden_layer_sizes=301, score=0.979, total=   2.9s
# [CV] hidden_layer_sizes=49 ...........................................
# [CV] ............... hidden_layer_sizes=49, score=0.983, total=   1.9s
# [CV] hidden_layer_sizes=49 ...........................................
# [CV] ............... hidden_layer_sizes=49, score=0.992, total=   1.9s
# [CV] hidden_layer_sizes=49 ...........................................
# /home/raul/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [CV] ............... hidden_layer_sizes=49, score=0.967, total=   2.2s
# [CV] hidden_layer_sizes=217 ..........................................
# [CV] .............. hidden_layer_sizes=217, score=0.988, total=   2.4s
# [CV] hidden_layer_sizes=217 ..........................................
# [CV] .............. hidden_layer_sizes=217, score=0.996, total=   2.4s
# [CV] hidden_layer_sizes=217 ..........................................
# [CV] .............. hidden_layer_sizes=217, score=0.975, total=   2.2s
# [CV] hidden_layer_sizes=93 ...........................................
# [CV] ............... hidden_layer_sizes=93, score=0.988, total=   1.8s
# [CV] hidden_layer_sizes=93 ...........................................
# [CV] ............... hidden_layer_sizes=93, score=0.992, total=   2.0s
# [CV] hidden_layer_sizes=93 ...........................................
# [CV] ............... hidden_layer_sizes=93, score=0.971, total=   1.8s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   30.6s finished

# %%
mlp_clf = random_search['MLP'].best_estimator_
print("\n\nBest estimator: \n{}".format(mlp_clf))
# Out:
# Best estimator:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=301, learning_rate='adaptive',
#               learning_rate_init=0.0005, max_fun=15000, max_iter=1300,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
mlp_clf_perfect = MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
              beta_2=0.999, early_stopping=False, epsilon=1e-08,
              hidden_layer_sizes=301, learning_rate='adaptive',
              learning_rate_init=0.0005, max_fun=15000, max_iter=1300,
              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
              power_t=0.5, random_state=None, shuffle=True, solver='adam',
              tol=0.0001, validation_fraction=0.1, verbose=False,
              warm_start=False)

# %%
history = mlp_clf_perfect.fit(X_train, y_train)
loss_values = history.history['loss']
epochs = range(1, len(loss_values)+1)

y_predict = mlp_clf_perfect.predict(X_test)
acc_mlp = accuracy_score(y_test, y_predict)
print(acc_mlp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-641a3f82a08c> in <module>
#       1 history = mlp_clf_perfect.fit(X_train, y_train)
# ----> 2 loss_values = history.history['loss']
#       3 epochs = range(1, len(loss_values)+1)
#       4
#       5 y_predict = mlp_clf_perfect.predict(X_test)
#
# AttributeError: 'MLPClassifier' object has no attribute 'history'
