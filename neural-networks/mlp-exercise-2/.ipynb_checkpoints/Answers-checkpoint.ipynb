# %% [markdown]
# ## Equipe : Raul Aquino e Wendell

# %% [markdown]
# ## Questão 1

# %%
#Imports.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import StratifiedShuffleSplit, RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
#Function for plotting the decision region.
def plot(X, y, model):
    clf = model
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                        np.arange(y_min, y_max, 0.1))
    
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.4)
    scat = plt.scatter(X[:, 0], X[:, 1], c=y,
                      s=20, edgecolor='k')
    
    legends = plt.legend(*scat.legend_elements(), loc="upper left", title="MLP")
    
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.show()

# %%
#loading the dataset.
df_ex5 = pd.read_csv('./dados-ex5.txt', names=['x1','x2','y'])
df_ex5
# Out:
#            x1        x2    y
# 0    0.771744 -0.548086  1.0
# 1    0.189416 -0.261982  1.0
# 2    0.918359  0.443277  0.0
# 3    1.021213 -0.488523  1.0
# 4    1.178442 -0.369193  1.0
# ..        ...       ...  ...
# 895  1.531981 -0.218318  1.0
# 896  0.038770 -0.219614  1.0
# 897 -0.641807  0.325579  0.0
# 898  0.628552  1.141872  0.0
# 899  0.102993  0.200450  1.0
#
# [900 rows x 3 columns]

# %%
#Separation in training and test data.
X = np.array(df_ex5.iloc[:,0:2])
y = np.array(df_ex5.iloc[:, -1])

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.20)

for train_index, test_index in sss.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
#Plotting the data.
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
plt.show()

# %% [markdown]
# ## 👇 Com a utilização do random_search conseguimos encontrar os parâmetros que melhores se adequam aos dados.

# %%
# Model pre-loadings:
mlp_clf = MLPClassifier(solver='adam', learning_rate='adaptive',max_iter=1300,
                        learning_rate_init=5e-04, tol=1e-4)

#Applying the size of hidden layers for my randon_search to find the form that best fits my data.
classifier = {'MLP': mlp_clf}
param_dist_dict = {'MLP': {"hidden_layer_sizes": list(np.arange(2,500))}}

random_search = dict((k,[]) for k in classifier.keys())

#Applying random_search.
for clf in param_dist_dict.keys():
    print('--------------------------', clf, '--------------------------')
    random_search[clf] = RandomizedSearchCV(classifier[clf], param_dist_dict[clf], cv=3, n_iter=5, 
                                            verbose=5, scoring='accuracy')
    
    #Training the model.
    random_search[clf].fit(X_train, y_train)
    
#     loss_values = random_search[clf].loss_curve_
#     print(loss_values)
# Out:
# -------------------------- MLP --------------------------
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] hidden_layer_sizes=411 ..........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .............. hidden_layer_sizes=411, score=0.979, total=   4.3s
# [CV] hidden_layer_sizes=411 ..........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.2s remaining:    0.0s
# [CV] .............. hidden_layer_sizes=411, score=0.988, total=   3.8s
# [CV] hidden_layer_sizes=411 ..........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    8.0s remaining:    0.0s
# [CV] .............. hidden_layer_sizes=411, score=1.000, total=   4.7s
# [CV] hidden_layer_sizes=74 ...........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   12.7s remaining:    0.0s
# [CV] ............... hidden_layer_sizes=74, score=0.971, total=   2.7s
# [CV] hidden_layer_sizes=74 ...........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   15.5s remaining:    0.0s
# [CV] ............... hidden_layer_sizes=74, score=0.983, total=   2.2s
# [CV] hidden_layer_sizes=74 ...........................................
# [CV] ............... hidden_layer_sizes=74, score=1.000, total=   2.1s
# [CV] hidden_layer_sizes=140 ..........................................
# [CV] .............. hidden_layer_sizes=140, score=0.979, total=   2.4s
# [CV] hidden_layer_sizes=140 ..........................................
# [CV] .............. hidden_layer_sizes=140, score=0.983, total=   2.4s
# [CV] hidden_layer_sizes=140 ..........................................
# [CV] .............. hidden_layer_sizes=140, score=1.000, total=   2.4s
# [CV] hidden_layer_sizes=302 ..........................................
# [CV] .............. hidden_layer_sizes=302, score=0.979, total=   3.5s
# [CV] hidden_layer_sizes=302 ..........................................
# [CV] .............. hidden_layer_sizes=302, score=0.983, total=   3.5s
# [CV] hidden_layer_sizes=302 ..........................................
# [CV] .............. hidden_layer_sizes=302, score=1.000, total=   3.6s
# [CV] hidden_layer_sizes=50 ...........................................
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] ............... hidden_layer_sizes=50, score=0.975, total=   2.3s
# [CV] hidden_layer_sizes=50 ...........................................
# [CV] ............... hidden_layer_sizes=50, score=0.983, total=   1.8s
# [CV] hidden_layer_sizes=50 ...........................................
# [CV] ............... hidden_layer_sizes=50, score=0.996, total=   2.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   43.7s finished

# %%
#Taking the best parameters (with the best score) to load my model.
mlp_clf = random_search['MLP'].best_estimator_
print("\n\nBest estimator: \n{}".format(mlp_clf))
# Out:
# Best estimator:
# MLPClassifier(hidden_layer_sizes=411, learning_rate='adaptive',
#               learning_rate_init=0.0005, max_iter=1300)

# %%
#Loading the best model.
mlp_clf_perfect = MLPClassifier(hidden_layer_sizes=411, learning_rate='adaptive',
              learning_rate_init=0.0005, max_iter=1300)

# %%
#Training again now with the loaded model, and taking your loss values and accuracy
mlp_clf_perfect.fit(X_train, y_train)
loss_values_perfect = mlp_clf_perfect.loss_curve_
final_loss_perfect = loss_values_perfect[-1]
print('the final loss = {:.3f}'.format(final_loss_perfect))

y_predict_perfect = mlp_clf_perfect.predict(X_test)
acc_mlp_perfect = accuracy_score(y_test, y_predict_perfect)
print('the accuracy = {:.3f}'.format(acc_mlp_perfect))

# print(loss_values_perfect)

plt.plot(loss_values_perfect)
plt.show()
# Out:
# the final loss = 0.040
# the accuracy = 1.000

# %%
plot(X_train, y_train, mlp_clf_perfect)

# %% [markdown]
# ## 👇 Para ir de acordo com a atividade irei testar 3 formas diferentes e pegar a melhor e a pior das 3
#
# `Agora vou fazer basicamente o que foi feito no item anterior porém com valores estimados por mim`

# %% [markdown]
# `mlp_clf_1`

# %%
mlp_clf_1 = MLPClassifier(hidden_layer_sizes=10, learning_rate_init=0.3, max_iter=10)

mlp_clf_1.fit(X_train, y_train)
loss_values_1 = mlp_clf_1.loss_curve_
final_loss_1 = loss_values_1[-1]

print(loss_values_1)

y_predict_1 = mlp_clf_1.predict(X_test)
acc_mlp_1 = accuracy_score(y_test, y_predict_1)
# Out:
# [0.5003844400038321, 0.35044712043135123, 0.3156382415157572, 0.2996202855258133, 0.27266474045227795, 0.25559735879967843, 0.23245133316999353, 0.20811538732164023, 0.179978277561625, 0.1617420056419617]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print('the final loss = {:.3f}'.format(final_loss_1))
print('the accuracy = {:.3f}'.format(acc_mlp_1))
# Out:
# the final loss = 0.162
# the accuracy = 0.928

# %%
plt.plot(loss_values_1)
plt.show()

# %% [markdown]
# `mlp_clf_2`

# %%
mlp_clf_2 = MLPClassifier(hidden_layer_sizes=100, learning_rate_init=0.03, max_iter=100)

mlp_clf_2.fit(X_train, y_train)
loss_values_2 = mlp_clf_2.loss_curve_
final_loss_2 = loss_values_2[-1]

print(loss_values_2)

y_predict_2 = mlp_clf_2.predict(X_test)
acc_mlp_2 = accuracy_score(y_test, y_predict_2)
# Out:
# [0.5270085965123783, 0.34590913586978206, 0.3057453728395432, 0.2705427130563574, 0.257194328839213, 0.2364917887987766, 0.2171592669351683, 0.19819485466925468, 0.17989481685663616, 0.16381839963612227, 0.14188013639985123, 0.11980704724829179, 0.10173614717001382, 0.08728928401189348, 0.07698726923732102, 0.07296308610426448, 0.05895303253023119, 0.05685504036155899, 0.050509366760101974, 0.04555455620628708, 0.04525790154533557, 0.04237568918327679, 0.04223412878676131, 0.038441264603348034, 0.037227391878155124, 0.041486151404549046, 0.03604600040151634, 0.03546220857832736, 0.03515180053166328, 0.03350494541307105, 0.03189968814514489, 0.0308135946987697, 0.030832498755460878, 0.029652315435859937, 0.030331331263884504, 0.03059579352161301, 0.02828030399024497, 0.03024155451583203, 0.02789749437189525, 0.02831616748844544, 0.028962296229131414, 0.027904428027751525, 0.02680237677187872, 0.027132228879358313, 0.027007799573598782, 0.027664136513378988, 0.0302535575311537, 0.027255266759088126, 0.028452429666856155, 0.025922388509047344, 0.025811423295819688, 0.026626275236655107, 0.024243519714274065, 0.027205697446745898, 0.025256218790161686, 0.026713594213747267, 0.027028963534374395, 0.02435700597356706, 0.027006848411685977, 0.02667500607988779, 0.024986920519966406, 0.027188540309489938, 0.02489616219913742, 0.0238065121944502, 0.0246126132096033, 0.023513191425734752, 0.024291508216621016, 0.026826231626569753, 0.024876809624765458, 0.026352977855598148, 0.024967272973314233, 0.025295183104760113, 0.022942499358077288, 0.023967564944043382, 0.022294261714812327, 0.025080046213946147, 0.023450865603648195, 0.02283270539246945, 0.024872481985791135, 0.02364516926569998, 0.023400086640735587, 0.024123051568243455, 0.02255590434245825, 0.02197189241235825, 0.022270777450884113, 0.021513128127525823, 0.024121261821230974, 0.020778414326265135, 0.022024249565660497, 0.021031807276642927, 0.020781356511085487, 0.021058188228089317, 0.021772259486548, 0.02085967634736888, 0.02135564677427448, 0.022998458072968762, 0.026321961904053174, 0.02369164387265564, 0.023287867498737746]

# %%
print('the final loss = {:.3f}'.format(final_loss_2))
print('the accuracy = {:.3f}'.format(acc_mlp_2))
# Out:
# the final loss = 0.023
# the accuracy = 0.994

# %%
plt.plot(loss_values_2)
plt.show()

# %% [markdown]
# `mlp_clf_3`

# %%
mlp_clf_3 = MLPClassifier(hidden_layer_sizes=1000, learning_rate_init=0.003, max_iter=1000)

mlp_clf_3.fit(X_train, y_train)
loss_values_3 = mlp_clf_3.loss_curve_
final_loss_3 = loss_values_3[-1]

print(loss_values_3)

y_predict_3 = mlp_clf_3.predict(X_test)
acc_mlp_3 = accuracy_score(y_test, y_predict_3)
# Out:
297118, 0.022367235037524507, 0.02217627495373065, 0.02197193353861314, 0.02198408493732245, 0.021886223428579918, 0.02202934188150703, 0.021776629933658528, 0.02186991678727673, 0.021867320841355883, 0.02191773484617064, 0.022732506377392065, 0.021514936775761734, 0.022439736982717732, 0.02208837850029355, 0.022525742197892325, 0.021743874461532312, 0.021521997289533714, 0.02133612108679335, 0.02151285283559683, 0.021487558894287974, 0.02131262801239254, 0.021353057084893216, 0.02103268235773749, 0.021010070642028537, 0.020894603365467963, 0.02112964403997989, 0.021094469501964586, 0.02082269683079 ...

# %%
print('the final loss = {:.3f}'.format(final_loss_3))
print('the accuracy = {:.3f}'.format(acc_mlp_3))
# Out:
# the final loss = 0.021
# the accuracy = 0.994

# %%
plt.plot(loss_values_3)
plt.show()

# %% [markdown]
# ### Como foi observado dos 3 testes, o primeiro foi o que se saiu pior (mlp_clf_1) e o segundo foi o que se saiu melhor (mlp_clf_2), superficie de decisão de cada um deles respectivamente:

# %%
plot(X_train, y_train, mlp_clf_1)

# %%
plot(X_train, y_train, mlp_clf_2)

# %% [markdown]
# ## Questão 2

# %% [markdown]
# - Explicar o problema associado ao dataset escolhido;
# `O dataset escolhido faz referência ao dataset MNIST, porém de uma maneira mais simplificada e reduzida. No original elas são representas 28x28, neste toy_dataset ele é somente 8x8`

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

digits = load_digits()

X = digits.data
y = digits.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
plt.gray() 
plt.matshow(digits.images[0]) 
plt.show()

# %%
clf_1 = MLPClassifier(hidden_layer_sizes=10, learning_rate_init=0.3, max_iter=10)

clf_1.fit(X_train, y_train)
# Out:
# /home/raul/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=10, learning_rate='constant',
#               learning_rate_init=0.3, max_fun=15000, max_iter=10, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
clf_2 = MLPClassifier(hidden_layer_sizes=100, learning_rate_init=0.03, max_iter=100)

clf_2.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=100, learning_rate='constant',
#               learning_rate_init=0.03, max_fun=15000, max_iter=100,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
clf_3 = MLPClassifier(hidden_layer_sizes=1000, learning_rate_init=0.003, max_iter=1000)

clf_3.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=1000, learning_rate='constant',
#               learning_rate_init=0.003, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %% [markdown]
# - Plotar a evolução da função custo (loss) ao longo do treinamento (épocas) para verificar a
# corretude do algoritmo de treinamento.

# %%
loss_values_digits_1 = clf_1.loss_curve_
plt.plot(loss_values_digits_1)
plt.show()

# %%
loss_values_digits_2 = clf_2.loss_curve_
plt.plot(loss_values_digits_2)
plt.show()

# %%
loss_values_digits_3 = clf_3.loss_curve_
plt.plot(loss_values_digits_3)
plt.show()

# %% [markdown]
# - Reportar taxas de acerto (ou erro) nos conjuntos de treinamento e teste para diferentes
# configurações da rede neural.

# %%
y_predict_1 = clf_1.predict(X_test)
acc_1 = accuracy_score(y_test, y_predict_1)
print('acc_1 = {}'.format(acc_1))
# Out:
# acc_1 = 0.08444444444444445

# %%
y_predict_2 = clf_2.predict(X_test)
acc_2 = accuracy_score(y_test, y_predict_2)
print('acc_2 = {}'.format(acc_2))
# Out:
# acc_2 = 0.9711111111111111

# %%
y_predict_3 = clf_3.predict(X_test)
acc_3 = accuracy_score(y_test, y_predict_3)
print('acc_3 = {}'.format(acc_3))
# Out:
# acc_3 = 0.9844444444444445
