# %% [markdown]
# ## Equipe : Raul Aquino e Wendell

# %% [markdown]
# #### Material de apoio
#
# https://www.youtube.com/watch?v=WEV61GmmPrk
#
# https://pytorch.org/tutorials/intermediate/char_rnn_classification_tutorial.html
#
# https://www.kaggle.com/rjtmehta99/e-d-a-of-chennai-hotel-reviews
#
# https://github.com/IFCE-Mestado-Ciencia-da-Computacao/PGM-2017.2/blob/master/Lista-2.ipynb

# %%
#Imports
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
import enchant
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#Download to complement vocabulary creation 
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger')

# %%
#RNN class where the model for this problem will be created.
class RNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim):
         
        super().__init__()
        
        self.embedding = nn.Embedding(input_dim, embedding_dim)
        
        self.gru = nn.GRU(embedding_dim, hidden_dim)
        
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, text):

        #text = [sent len, batch size]
        
        embedded = self.embedding(text)
        
        #embedded = [sent len, batch size, emb dim]
        
        output, hidden = self.gru(embedded)
        
        #output = [sent len, batch size, hid dim]
        #hidden = [1, batch size, hid dim]
        
        assert torch.equal(output[-1,:,:], hidden.squeeze(0))
        
        return self.fc(hidden.squeeze(0))
    
    def initHidden(self):
        return torch.zeros(1, self.hidden_size)

# %%
#Loading the dataset in df
df = pd.read_csv('./chennai_reviews.csv')
#Showing the dataset's inconsistencies
print(df.shape)
df.head()
# Out:
# (4768, 9)
#             Hotel_name                           Review_Title  \
# 0  Accord Metropolitan  Excellent comfortableness during stay
# 1  Accord Metropolitan                    Not too comfortable
# 2  Accord Metropolitan                                    NaN
# 3  Accord Metropolitan                             Best hotel
# 4  Accord Metropolitan                                    NaN
#
#                                          Review_Text Sentiment  \
# 0  Its really nice place to stay especially for b...         3
# 1  It seems that hotel does not check the basic a...         1
# 2  Worst hotel I have ever encountered. I will ne...         1
# 3  Had a good time in this hotel and the staff Ku...         3
# 4  good hotel and staff Veg food good non veg bre...         3
#
#   Rating_Percentage  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0               100         NaN        NaN         NaN         NaN
# 1                20         NaN        NaN         NaN         NaN
# 2                20         NaN        NaN         NaN         NaN
# 3               100         NaN        NaN         NaN         NaN
# 4               100         NaN        NaN         NaN         NaN

# %%
#Showing information about the dataset and seeing its inconsistencies
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4768 entries, 0 to 4767
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Hotel_name         4768 non-null   object
#  1   Review_Title       4341 non-null   object
#  2   Review_Text        4767 non-null   object
#  3   Sentiment          4766 non-null   object
#  4   Rating_Percentage  4767 non-null   object
#  5   Unnamed: 5         64 non-null     float64
#  6   Unnamed: 6         3 non-null      object
#  7   Unnamed: 7         1 non-null      float64
#  8   Unnamed: 8         1 non-null      float64
# dtypes: float64(3), object(6)
# memory usage: 335.4+ KB

# %%
#Remove noisy data from column 6,7,8,9
#Remove the columns that have 'unnamed' in the column name
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#                  Hotel_name                           Review_Title  \
# 0       Accord Metropolitan  Excellent comfortableness during stay
# 1       Accord Metropolitan                    Not too comfortable
# 2       Accord Metropolitan                                    NaN
# 3       Accord Metropolitan                             Best hotel
# 4       Accord Metropolitan                                    NaN
# ...                     ...                                    ...
# 4763  Hyatt Regency Chennai     Fifth stay and excellent as always
# 4764  Hyatt Regency Chennai                              satisfied
# 4765  Hyatt Regency Chennai                                    NaN
# 4766  Hyatt Regency Chennai                          Dissappointed
# 4767  Hyatt Regency Chennai             Great Stay at this hotel!!
#
#                                             Review_Text Sentiment  \
# 0     Its really nice place to stay especially for b...         3
# 1     It seems that hotel does not check the basic a...         1
# 2     Worst hotel I have ever encountered. I will ne...         1
# 3     Had a good time in this hotel and the staff Ku...         3
# 4     good hotel and staff Veg food good non veg bre...         3
# ...                                                 ...       ...
# 4763  My fifth stay at the hotel for business. Rooms...         3
# 4764                                          enjoyable         3
# 4765  Most impressive service by staff in all areas....         3
# 4766  The linens were smelling bad, and the elevator...         1
# 4767  Stayed at the Hyatt in Chennai for the first t...         3
#
#      Rating_Percentage
# 0                  100
# 1                   20
# 2                   20
# 3                  100
# 4                  100
# ...                ...
# 4763               100
# 4764               100
# 4765                80
# 4766                20
# 4767               100
#
# [4768 rows x 5 columns]

# %%
#Replace empty cells with 'Unavailable' in Review_Title column 
values = {'Review_Text': 'Unavailable'}
df = df.fillna(value=values)
df
# Out:
#                  Hotel_name                           Review_Title  \
# 0       Accord Metropolitan  Excellent comfortableness during stay
# 1       Accord Metropolitan                    Not too comfortable
# 2       Accord Metropolitan                                    NaN
# 3       Accord Metropolitan                             Best hotel
# 4       Accord Metropolitan                                    NaN
# ...                     ...                                    ...
# 4763  Hyatt Regency Chennai     Fifth stay and excellent as always
# 4764  Hyatt Regency Chennai                              satisfied
# 4765  Hyatt Regency Chennai                                    NaN
# 4766  Hyatt Regency Chennai                          Dissappointed
# 4767  Hyatt Regency Chennai             Great Stay at this hotel!!
#
#                                             Review_Text Sentiment  \
# 0     Its really nice place to stay especially for b...         3
# 1     It seems that hotel does not check the basic a...         1
# 2     Worst hotel I have ever encountered. I will ne...         1
# 3     Had a good time in this hotel and the staff Ku...         3
# 4     good hotel and staff Veg food good non veg bre...         3
# ...                                                 ...       ...
# 4763  My fifth stay at the hotel for business. Rooms...         3
# 4764                                          enjoyable         3
# 4765  Most impressive service by staff in all areas....         3
# 4766  The linens were smelling bad, and the elevator...         1
# 4767  Stayed at the Hyatt in Chennai for the first t...         3
#
#      Rating_Percentage
# 0                  100
# 1                   20
# 2                   20
# 3                  100
# 4                  100
# ...                ...
# 4763               100
# 4764               100
# 4765                80
# 4766                20
# 4767               100
#
# [4768 rows x 5 columns]

# %%
#Replace noisy data in column Sentiment with column mean value
df['Sentiment'] = df['Sentiment'].str.replace(r'[^1-9]','')

#Remove white spaces
df['Sentiment'] = df['Sentiment'].str.replace(r'[s+]','')

#Fill missing values
df['Sentiment'] = df['Sentiment'].fillna(2)
df
# Out:
#                  Hotel_name                           Review_Title  \
# 0       Accord Metropolitan  Excellent comfortableness during stay
# 1       Accord Metropolitan                    Not too comfortable
# 2       Accord Metropolitan                                    NaN
# 3       Accord Metropolitan                             Best hotel
# 4       Accord Metropolitan                                    NaN
# ...                     ...                                    ...
# 4763  Hyatt Regency Chennai     Fifth stay and excellent as always
# 4764  Hyatt Regency Chennai                              satisfied
# 4765  Hyatt Regency Chennai                                    NaN
# 4766  Hyatt Regency Chennai                          Dissappointed
# 4767  Hyatt Regency Chennai             Great Stay at this hotel!!
#
#                                             Review_Text Sentiment  \
# 0     Its really nice place to stay especially for b...         3
# 1     It seems that hotel does not check the basic a...         1
# 2     Worst hotel I have ever encountered. I will ne...         1
# 3     Had a good time in this hotel and the staff Ku...         3
# 4     good hotel and staff Veg food good non veg bre...         3
# ...                                                 ...       ...
# 4763  My fifth stay at the hotel for business. Rooms...         3
# 4764                                          enjoyable         3
# 4765  Most impressive service by staff in all areas....         3
# 4766  The linens were smelling bad, and the elevator...         1
# 4767  Stayed at the Hyatt in Chennai for the first t...         3
#
#      Rating_Percentage
# 0                  100
# 1                   20
# 2                   20
# 3                  100
# 4                  100
# ...                ...
# 4763               100
# 4764               100
# 4765                80
# 4766                20
# 4767               100
#
# [4768 rows x 5 columns]

# %%
#Taking the average of the correct values that are [1,2,3]
aux = 0
for i in range(len(df.Sentiment)):
    if (df.Sentiment[i] != '' and int(df.Sentiment[i]) <= 3):
        aux += int(df.Sentiment[i])
aux = round(aux/len(df.Sentiment))
print(aux)
# Out:
# 3

# %%
#Leaving all variables in the string pattern.
for i in range(len(df.Sentiment)):
    form = 0
    if df.Sentiment[i] == '':
        df.Sentiment[i] = str(aux)
        
#Leaving all ratings in lower case.
df['Review_Text'] = df['Review_Text'].apply(lambda x:x.lower())

# %%
#Changing all values outside the pattern to the rounded average of the data.
for i in range(len(df.Sentiment)):
    if int(df.Sentiment[i]) > 3:
        df.Sentiment[i] = str(aux)

# %%
#Removing columns that are not needed
df = df.drop(['Hotel_name', 'Review_Title'], axis=1)
df.head()
# Out:
#                                          Review_Text Sentiment  \
# 0  its really nice place to stay especially for b...         3
# 1  it seems that hotel does not check the basic a...         1
# 2  worst hotel i have ever encountered. i will ne...         1
# 3  had a good time in this hotel and the staff ku...         3
# 4  good hotel and staff veg food good non veg bre...         3
#
#   Rating_Percentage
# 0               100
# 1                20
# 2                20
# 3               100
# 4               100

# %%
# Find word index from all_letters, e.g. "a" = 0
def wordToIndex(word):
    return np.where(all_words == word)[0][0]

# Just for demonstration, turn a letter into a <1 x n_letters> Tensor
def wordToTensor(word):
    tensor = torch.zeros(1, len(all_words))
    tensor[0][wordToIndex(word)] = 1
    return tensor

# Turn a line into a <line_length x 1 x n_letters>,
# or an array of one-hot letter vectors
def lineToTensor(line):
    tensor = torch.zeros(len(line), 1, len(all_words))
    for li, word in enumerate(line):
        tensor[li][0][wordToIndex(word)] = 1
    return tensor

# %%
#Convert to lower case
def preprocess(column_name):
    column_name = column_name.str.lower()
    column_name = column_name.str.replace(r"^[a-zA-Z]\s+","")
    column_name = column_name.str.replace(r"wouldn't","would not")
    column_name = column_name.str.replace(r"ain't","am not")
    column_name = column_name.str.replace(r"isn't","is not")
    column_name = column_name.str.replace(r"aren't","are not")
    column_name = column_name.str.replace(r"can't","can not")
    column_name = column_name.str.replace(r"shouldn't","should not")
    column_name = column_name.str.replace(r"shan't","shall not")
    column_name = column_name.str.replace(r"won't","will not")
    column_name = column_name.str.replace(r"hasn't","has not")
    column_name = column_name.str.replace(r"hadn't","had not")
    column_name = column_name.str.replace(r"don't","do not")
    column_name = column_name.str.replace(r"couldn't","could not")
    column_name = column_name.str.replace(r"didn't","did not")
    column_name = column_name.str.replace(r"aint","am not")
    column_name = column_name.str.replace(r"isnt","is not")
    column_name = column_name.str.replace(r"wouldnt","would not")
    column_name = column_name.str.replace(r"aint","am not")
    column_name = column_name.str.replace(r"isnt","is not")
    column_name = column_name.str.replace(r"arent","are not")
    column_name = column_name.str.replace(r"cant","can not")
    column_name = column_name.str.replace(r"shouldnt","should not")
    column_name = column_name.str.replace(r"shant","shall not")
    column_name = column_name.str.replace(r"wont","will not")
    column_name = column_name.str.replace(r"hasnt","has not")
    column_name = column_name.str.replace(r"hadnt","had not")
    column_name = column_name.str.replace(r"dont","do not")
    column_name = column_name.str.replace(r"couldnt","could not")
    column_name = column_name.str.replace(r"didnt","did not")
    column_name = column_name.str.replace(r"aint","am not")
    column_name = column_name.str.replace(r"isnt","is not")    

    return column_name

# %%
#Applying the function
df.Review_Text = preprocess(df.Review_Text)

# %%
#Separating the columns and checking if they are the same size.
review_text = df.Review_Text
sentiment = df.Sentiment
print(len(review_text), len(sentiment))
print(len(review_text) == len(sentiment))
# Out:
# 4768 4768
# True

# %%
#Filtering only the words for the sentence formation
review_tag = []
dictionary_en_US = enchant.Dict("en_US")

palavras = []

for r in review_text:
    tag_list = []
    tokens = nltk.word_tokenize(str(r))
    #split_r = str(r).split()
    #palavras = set(split_r)
    english_stop_words = set(stopwords.words('english'))
    palavras_filtradas = set(tokens) - english_stop_words
    palavras_filtradas = set(filter(dictionary_en_US.check, palavras_filtradas))
    tagged = nltk.pos_tag(palavras_filtradas)
    
    for t in tagged:
        if(t[1] == 'VERB' or t[1] == 'RB' or t[1] == 'JJ' or t[1] == 'RBR'):
            tag_list.append(t[0])
            palavras.append(t[0])
            
    review_tag.append(tag_list)
print(review_tag)
# Out:
# [['nice', 'especially', 'really'], ['fix', 'hectic', 'basic'], ['worst', 'never', 'future', 'ever'], ['stay', 'back', 'happy', 'good', 'sure', 'pleasant'], ['good'], ['helpful', 'always', 'great'], ['second', 'great', 'excellent', 'long', 'wall', 'hot', 'mostly', 'first'], ['friendly', 'awesome', 'great'], ['nice'], ['extremely', 'comfortable', 'chefs', 'good', 'oven', 'helpful'], ['decent', 'overall', 'restaurant', 'pleasant'], ['single', 'perfect', 'stay', 'excellent', 'nice', 'double', 'cleanliness', 'also', 'great'], ['close', 'spacious', 'courteous', 'simple', 'check-in', 'also', 'clean'], ['certainly', 'nice', 'good', 'complimentary', 'also', 'airport'], ['super', 'otherwise', 'bad', 'courteous', 'pleasant'], ['smooth', 'zodiac', 'english', 'negative', 'good', 'easily', 'accessible'], ['table', 'good', 'bad', 'much'], ['also', 'recommend', 'good', 'experience', 'accord'], ['overall', 'spacious', 'good', 'complimentary'], ['worth', 'small', 'good', 'suitable'], ['good', 'etc'], ['centrally', 'good', 'courteous', 'also', 'eat'], ['excellent', 'overall', 'nice', 'well', 'level', 'cleanliness'], ['fine', 'purpose'], ['stay', 'comfortable', 'nice', 'good', 'purpose'], ['stay', 'awesome', 'many', 'restaurant', 'good', 'courteous', 'also', 'great'], ['friendly', 'regular', 'charge'], ['also', 'service', 'good', 'free'], ['nice', 'good', 'close'], ['excellent', 'friendly', 'pleasant'], ['nice', 'pleasant', 'professional', 'fantastic'], ['even', 'sold-out', 'complementary', 'perhaps', 'basic', 'almost'], ['happy'], ['comfortable', 'single', 'overall', 'adequate', 'small'], ['nice', 'comfortable'], ['overly', 'quite', 'comfortable', 'impossible', 'nice', 'safe', 'physical', 'detract', 'little', 'clean', 'large'], ['perfect'], ['good'], ['different', 'international', 'dirty', 'table', 'poor', 'accept'], ['well', 'extraordinary', 'mam'], ['friendly', 'warm', 'old', 'mam', 'overall', 'front', 'well', 'cradle', 'complimentary', 'pleasant', 'even', 'wide'], ['even', 'old', 'bath', 'white'], ['old', 'quite', 'breakfast', 'long', 'good', 'musty', 'even'], [], ['probably', 'small', 'better', 'definitely', 'outstanding', 'mainland', 'plane', 'accessible', 'almost'], ['thankfully', 'good', 'disappointed', 'else'], ['enough'], ['good'], ['definitely', 'travel', 'dirty', 'close', 'bad', 'rather', 'cheap', 'first', 'hotel', 'soon', 'touch'], ['several', 'central', 'well', 'nice', 'easy', 'big', 'nearby'], ['old', 'small', 'outdated'], ['trained', 'long', 'well', 'possibly', 'good', 'acceptable', 'check-in', 'much', 'especially', 'star'], ['handle', 'properly', '4-5', 'layouts', 'terrible', 'pick', 'worth', 'great'], ['good'], ['hot'], ['centrally', 'spacious', 'bad', 'great'], ['check-in', 'helpful', 'good', 'wait'], ['perfect', 'cooperative', 'visa', 'beautiful', 'well', 'consulate', 'mostly', 'also', 'helpful'], ['friendly', 'centrally', 'long', 'good', 'poor', 'decent'], ['stay', 'excellent', 'close', 'big', 'pleasant'], ['great'], ['friendly', 'spite', 'finally', 'solution', 'nearly'], ['polite', 'available', 'nice', 'well', 'future', 'much', 'professional', 'happy'], ['back', 'soft', 'always', 'good', 'bad', 'hot', 'also', 'high', 'faucet'], ['overall', 'quickly', 'opposite', 'good', 'enough'], ['unkempt', 'poorly', 'dish', 'pickle', 'apart', 'much', 'awful', 'tasted', 'enough', 'almost'], ['outside', 'clean', 'dirty', 'well', 'good'], ['positive', 'buffet'], ['well'], ['disappointed', 'sure'], ['friendly', 'excellent', 'good', 'helpful', 'wholesome'], ['good'], ['sink'], ['nice', 'also', 'good', 'clean', 'great'], ['good', 'else', 'great'], ['excellent', 'nice', 'friendly', 'good', 'courteous', 'clean'], ['need', 'really'], ['also', 'good', 'poor'], ['probably', 'great', 'excellent', 'expensive', 'good', 'high'], ['excellent', 'greatly', 'great'], ['add', 'smile', 'much-', 'front', 'many', 'come', 'door-i', 'helpful', 'in-', 'anna', 'enough', 'nearby', 'great'], ['much', 'definitely', 'next'], ['old', 'good', 'bad', 'clean'], ['attentive ...

# %%
#Removing empty reviews.
sentiment1 = []
review_tag1 = []

for i in range(len(review_tag)):
    if len(review_tag[i]) != 0:
        sentiment1.append(list(sentiment)[i])
        review_tag1.append(review_tag[i])

# %%
#Taking all the unique words.
all_words = np.unique(palavras)
len(np.unique(palavras))
# Out:
# 1918

# %%
#Passing the parameters to the RNN
n_categories = 3
EMBEDDING_DIM = 100
HIDDEN_DIM = 256
OUTPUT_DIM = 1

rnn = RNN(len(all_words), EMBEDDING_DIM, HIDDEN_DIM, n_categories)

# %%
#Separating in training and testing.
x_train, x_test, y_train, y_test = train_test_split(review_tag1, sentiment1, test_size=0.33)

# %%
import random
feelings = np.array([1,2,3])
def randomChoice(l):
    return l[random.randint(0, len(l) - 1)]

def randomTrainingExample():
    category = randomChoice(feelings)
    position = randomChoice(np.where(np.array(y_train) == str(category))[0])
    line = x_train[position]
    
    category_tensor = torch.tensor([np.where(feelings == category)[0]][0], dtype=torch.long)
    
    line_tensor = lineToTensor(line)
    
    return category, line, category_tensor, line_tensor

for i in range(10):
    category, line, category_tensor, line_tensor = randomTrainingExample()
    print('category =', category, '/ line =', line)
# Out:
# category = 3 / line = ['awesome', 'indeed', 'luxurious', 'behavior', 'front', 'well', 'spacious', 'outer', 'good', 'courteous', 'inner', 'also']
# category = 3 / line = ['narrow', 'assist', 'easy', 'good', 'courteous', 'anna']
# category = 1 / line = ['full', 'bad', 'pillow', "o'clock", 'also']
# category = 1 / line = ['small', 'next', 'dirty', 'bad', 'double', 'also']
# category = 1 / line = ['limited', 'average', 'cleanliness']
# category = 3 / line = ['medical', 'really', 'excellent', 'easy', 'odd', 'first', 'short', 'memorable']
# category = 3 / line = ['nice', 'friendly', 'courteous', 'fabulous']
# category = 3 / line = ['lively', 'main', 'local', 'nice', 'worth']
# category = 2 / line = ['helpful', 'close', 'free']
# category = 3 / line = ['tasty', 'nice', 'anywhere', 'pleasant', 'high', 'visited']

# %%
#Training.
learning_rate = 0.005

def train(category_tensor, line_tensor):
    hidden = rnn.initHidden()

    rnn.zero_grad()
    
    #print(line_tensor.size()[0])

    for i in range(line_tensor.size()[0]):
        output1, hidden = rnn(line_tensor[i], hidden)

    loss = criterion(output1, category_tensor)
    loss.backward()

    # Add parameters' gradients to their values, multiplied by learning rate
    for p in rnn.parameters():
        p.data.add_(p.grad.data, alpha=-learning_rate)

    return output, loss.item()

# %%
#Checks the category corresponds to the review output. If so, type the symbol '✓'. If not, write the symbol '✗'
import time
import math

n_iters = 100000
print_every = 5000
plot_every = 1000

criterion = nn.NLLLoss()

# Keep track of losses for plotting
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

start = time.time()

for iter in range(1, n_iters + 1):
    category, line, category_tensor, line_tensor = randomTrainingExample()
    output, loss = train(category_tensor, line_tensor)
    current_loss += loss

    # Print iter number, loss, name and guess
    if iter % print_every == 0:
        guess, guess_i = categoryFromOutput(output)
        correct = '✓' if guess == category else '✗ (%s)' % category
        print('%d %d%% (%s) %.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), loss, line, guess, correct))

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7dc7e075039c> in <module>
#      24 for iter in range(1, n_iters + 1):
#      25     category, line, category_tensor, line_tensor = randomTrainingExample()
# ---> 26     output, loss = train(category_tensor, line_tensor)
#      27     current_loss += loss
#      28
#
# <ipython-input-36-bdda881b3dd4> in train(category_tensor, line_tensor)
#       3
#       4 def train(category_tensor, line_tensor):
# ----> 5     hidden = rnn.initHidden()
#       6
#       7     rnn.zero_grad()
#
# <ipython-input-32-2f49256229c3> in initHidden(self)
#      28         return self.fc(hidden.squeeze(0))
#      29     def initHidden(self):
# ---> 30         return torch.zeros(1, self.hidden_size)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     945             if name in modules:
#     946                 return modules[name]
# --> 947         raise AttributeError("'{}' object has no attribute '{}'".format(
#     948             type(self).__name__, name))
#     949
#
# AttributeError: 'RNN' object has no attribute 'hidden_size'

# %%
#Plotting the error.
plt.figure()
plt.plot(all_losses)

# %%
#Predict
def evaluate(line_tensor):
    hidden = rnn.initHidden()

    for i in range(line_tensor.size()[0]):
        output, hidden = rnn(line_tensor[i], hidden)

    return output

def predict(input_line, n_predictions=3):
    print('\n> %s' % input_line)
    with torch.no_grad():
        output = evaluate(lineToTensor(input_line))

        # Get top N categories
        topv, topi = output.topk(n_predictions, 1, True)
        predictions = []

        for i in range(n_predictions):
            value = topv[0][i].item()
            category_index = topi[0][i].item()
            print('(%.2f) %s' % (value, feelings[category_index]))
            predictions.append([value, feelings[category_index]])

for i in range(5):
    predict(x_test[i])
